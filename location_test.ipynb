# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/gdrive/MyDrive/Person_Counting/street.png")

cv2.putText(img, 'In front of shop : 3', (150, 640), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 255), 3)
cv2.putText(img, 'Person being tracked : 16', (150, 740), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)

img = cv2.line(img, (0, 503), (658, 503), (0, 255, 255), thickness=2)
img = cv2.line(img, (428, 333), (927, 333), (0, 255, 255), thickness=2)

height, width = img.shape[:2]
# 이미지 크기를 비율에 맞게 재조정 합니다. 
ratio = 1280.0 / width
dimension = (1280, int(height * ratio))
resized = cv2.resize(img, dimension, interpolation = cv2.INTER_AREA)
cv2_imshow(resized)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F9A768E0CD0>
